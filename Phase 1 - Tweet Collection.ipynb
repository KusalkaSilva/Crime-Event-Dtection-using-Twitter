# %%
# requests to the API
import requests
import os
import json
import pandas as pd
import csv
import datetime
import dateutil.parser
import unicodedata
import time

# %%
#setting the BEARER TOKEN as an input variable
os.environ['TOKEN'] = #'BEARER TOKEN'#

# %%
#gFunction to retrieve the token from the environment
def auth():
    return os.getenv('TOKEN')

# %%
#Function to request the endpoint and the parameters
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #full-archive search endpoint
    #defining parameters
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source,entities',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "(abduct OR abuse OR arrested OR arson OR assault OR burglary OR charged OR convicted OR crime OR cybercrime OR fraud OR homicide OR investigation OR jailed OR kidnap OR knifecrime OR manslaughter OR molestation OR murder police OR rape OR robbery OR seized OR sentenced OR shooting OR smuggle OR smuggling OR stabbing OR theft OR trafficking OR vandalism) place_country:GB has:geo -is:nullcast -is:retweet lang:en"
start_time = "2021-01-01T00:00:00.000Z"
end_time = "2021-12-31T00:00:00.000Z"
max_results = 500

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(json_response, indent=4))
# Out:
# {
#     "data": [
#         {
#             "id": "1476703915957698564",
#             "author_id": "325597286",
#             "created_at": "2021-12-30T23:57:04.000Z",
#             "conversation_id": "1476703915957698564",
#             "entities": {
#                 "urls": [
#                     {
#                         "start": 88,
#                         "end": 111,
#                         "url": "https://t.co/824Pkc2a17",
#                         "expanded_url": "https://twitter.com/Man_of_Rohan_/status/1476703915957698564/photo/1",
#                         "display_url": "pic.twitter.com/824Pkc2a17",
#                         "media_key": "3_1476703913906692101"
#                     }
#                 ]
#             },
#             "text": "Tell me you're guilty of sexual abuse without telling me you're guilty of sexual abuse. https://t.co/824Pkc2a17",
#             "source": "Twitter for Android",
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 2,
#                 "reply_count": 0,
#                 "like_count": 21,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "537b8c5518197832"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "id": "1476703071858311173",
#             "author_id": "61133020",
#             "created_at": "2021-12-30T23:53:42.000Z",
#             "conversation_id": "1476592672395730947",
#             "text": "@HodlShib1 @metpoliceuk @RingFinancial What I know is you report this by action fraud or on the police web page or contact the police via 101",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476612562418651144"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 11,
#                         "end": 23,
#                         "username": "metpoliceuk",
#                         "id": "66967746"
#                     },
#                     {
#                         "start": 24,
#                         "end": 38,
#                         "username": "RingFinancial",
#                         "id": "1456612933987880960"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "038247c1b5bb34c9"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1402724907310518301"
#         },
#         {
#             "id": "1476701556590399491",
#             "author_id": "40628326",
#             "created_at": "2021-12-30T23:47:41.000Z",
#             "conversation_id": "1476497525163057152",
#             "text": "@Life_Disrupted @rosedavidrose10 Well using the MET police as precedent. As the offence happened a while ago they can't investigate it \ud83e\udd37\u200d\u2642\ufe0f",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476497525163057152"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 15,
#                         "username": "Life_Disrupted",
#                         "id": "889039269637091330"
#                     },
#                     {
#                         "start": 16,
#                         "end": 32,
#                         "username": "rosedavidrose10",
#                         "id": "517320553"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 1,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "3a440bee2d136c16"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "889039269637091330"
#         },
#         {
#             "id": "1476701478735777800",
#             "author_id": "1419281160543277057",
#             "created_at": "2021-12-30T23:47:22.000Z",
#             "conversation_id": "1476462210822156289",
#             "text": "@tramowl @mrdanwalker What crime?",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476463377924960258"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 8,
#                         "username": "tramowl",
#                         "id": "3015001894"
#                     },
#                     {
#                         "start": 9,
#                         "end": 21,
#                         "username": "mrdanwalker",
#                         "id": "47945492"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "53b67b1d1cc81a51"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "3015001894"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 128,
#                         "end": 137,
#                         "probability": 0.8722,
#                         "type": "Person",
#                         "normalized_text": "Ms Maxwell"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "start": 284,
#                         "end": 307,
#                         "url": "https://t.co/krQsQqtkG2",
#                         "expanded_url": "https://twitter.com/BBCNews/status/1476338134254301193",
#                         "display_url": "twitter.com/BBCNews/status\u2026"
#                     }
#                 ]
#             },
#             "id": "1476701445034553344",
#             "author_id": "635288872",
#             "created_at": "2021-12-30T23:47:14.000Z",
#             "conversation_id": "1476701445034553344",
#             "text": "Genuinely really concerned about the main stream media\u2019s reporting of this case. I\u2019ve heard various outlets today use the term \u2018Ms Maxwell\u2019s accusers\u2019. She is a convicted sex offender &amp; they are victims not accusers. Sounds conspiratorial but rich/powerful influencing reporting? https://t.co/krQsQqtkG2",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "quoted",
#                     "id": "1476338134254301193"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 2,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "60160252aeb7e3e5"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 56,
#                         "end": 61,
#                         "probability": 0.4981,
#                         "type": "Organization",
#                         "normalized_text": "Tories"
#                     },
#                     {
#                         "start": 140,
#                         "end": 145,
#                         "probability": 0.9965,
#                         "type": "Place",
#                         "normalized_text": "London"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 11,
#                         "username": "gosports33",
#                         "id": "97000050"
#                     },
#                     {
#                         "start": 12,
#                         "end": 22,
#                         "username": "SadiqKhan",
#                         "id": "19397942"
#                     }
#                 ]
#             },
#             "id": "1476701066741886976",
#             "author_id": "3214353536",
#             "created_at": "2021-12-30T23:45:44.000Z",
#             "conversation_id": "1476671757759262727",
#             "text": "@gosports33 @SadiqKhan Blame government policies, mate. Tories cut police/youth services etc since 2010. Traffic\u2019s always been a problem in London, better now in my experience. LTNs are funded by govt, introduced by local councils, popular with residents. TfL doing fine until covid. Next!",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476681987721240582"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 1,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "5de8cffc145c486b"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "97000050"
#         },
#         {
#             "id": "1476700470324477961",
#             "author_id": "486896531",
#             "created_at": "2021-12-30T23:43:22.000Z",
#             "conversation_id": "1476699837483606023",
#             "text": "@_Moonbeam_Sky WTF. They have that patients details. This should be pursued by the nursing staff who were victims of this actual hate crime in the civil courts if necessary- probably able to argue the trust failed in duty of care too &amp; potentially police. Raging \ud83d\ude21",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476699837483606023"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 14,
#                         "username": "_Moonbeam_Sky",
#                         "id": "2450796689"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 1,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "5f73d127c7ccf9d9"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "2450796689"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 194,
#                         "end": 206,
#                         "probability": 0.996,
#                         "type": "Person",
#                         "normalized_text": "Prince Andrew"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 15,
#                         "username": "Jonathanlufc64",
#                         "id": "1123693313369026561"
#                     }
#                 ]
#             },
#             "id": "1476699651843706880",
#             "author_id": "1240285175768104962",
#             "created_at": "2021-12-30T23:40:07.000Z",
#             "conversation_id": "1476691853621747716",
#             "text": "@Jonathanlufc64 I'd actually seriously would love to go to a confession,  just to see the look on the priest face when he walks out the box, give him a little wink \ud83d\ude09 , while he's sweating like Prince Andrew on rape charge",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476696696960786436"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 3,
#                 "like_count": 4,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "6863fd050de21120"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1123693313369026561"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 38,
#                         "end": 46,
#                         "probability": 0.5313,
#                         "type": "Place",
#                         "normalized_text": "SureStart"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 13,
#                         "username": "teddyboybass",
#                         "id": "819531477402742784"
#                     },
#                     {
#                         "start": 14,
#                         "end": 24,
#                         "username": "SadiqKhan",
#                         "id": "19397942"
#                     }
#                 ]
#             },
#             "id": "1476699587943542789",
#             "author_id": "3214353536",
#             "created_at": "2021-12-30T23:39:52.000Z",
#             "conversation_id": "1476671757759262727",
#             "text": "@teddyboybass @SadiqKhan Tory cuts in SureStart/youth services/police/probation/courts/children\u2019s homes\u2026",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476682900879904773"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 3,
#                 "like_count": 2,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "5de8cffc145c486b"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "819531477402742784"
#         },
#         {
#             "id": "1476699084991967234",
#             "author_id": "82304352",
#             "created_at": "2021-12-30T23:37:52.000Z",
#             "conversation_id": "1476691828623749120",
#             "text": "@RCutcher Yes it was mate. Unbelievable scenes as you can imagine. Overtime was murder. Never seen such a celebration for a foul throw \ud83d\ude02",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476694642452271104"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 9,
#                         "username": "RCutcher",
#                         "id": "157625188"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 5,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "1f592b82aea688ff"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "157625188"
#         },
#         {
#             "id": "1476699083255562241",
#             "author_id": "113154962",
#             "created_at": "2021-12-30T23:37:51.000Z",
#             "conversation_id": "1476689492249653257",
#             "text": "@Ben_Met And where\u2019s the foul mouthed abuse in the tweet you are responding to - no, just a valid political point which gets abuse from you",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476696898287382529"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 8,
#                         "username": "Ben_Met",
#                         "id": "224599132"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "7c0c5be51311791a"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "224599132"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 93,
#                         "end": 102,
#                         "probability": 0.6347,
#                         "type": "Person",
#                         "normalized_text": "Lord Geidt"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "start": 120,
#                         "end": 143,
#                         "url": "https://t.co/vbRgpcyrgS",
#                         "expanded_url": "https://twitter.com/mikegalsworthy/status/1476643038613188617",
#                         "display_url": "twitter.com/mikegalsworthy\u2026"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 104,
#                         "end": 119,
#                         "username": "mikegalsworthy",
#                         "id": "34247411"
#                     }
#                 ]
#             },
#             "id": "1476698816019677188",
#             "author_id": "379368170",
#             "created_at": "2021-12-30T23:36:48.000Z",
#             "conversation_id": "1476698816019677188",
#             "text": "The PM could literally murder someone, apologies for it and this would still get accepted by Lord Geidt @mikegalsworthy https://t.co/vbRgpcyrgS",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "quoted",
#                     "id": "1476643038613188617"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "03a5820911d90b76"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 98,
#                         "end": 104,
#                         "probability": 0.5209,
#                         "type": "Product",
#                         "normalized_text": "Twitter"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "start": 114,
#                         "end": 137,
#                         "url": "https://t.co/Q2UMi7ydQv",
#                         "expanded_url": "https://twitter.com/ukgaragefan/status/1476698658494156802/photo/1",
#                         "display_url": "pic.twitter.com/Q2UMi7ydQv",
#                         "media_key": "3_1476698656422170627"
#                     }
#                 ]
#             },
#             "id": "1476698658494156802",
#             "author_id": "1298562503581073408",
#             "created_at": "2021-12-30T23:36:10.000Z",
#             "conversation_id": "1476698658494156802",
#             "text": "Harassment and abuse? I'd expect nothing less from this famously nasty piece of work. Good to see Twitter agrees. https://t.co/Q2UMi7ydQv",
#             "source": "Twitter for Android",
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 1,
#                 "reply_count": 0,
#                 "like_count": 5,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "1c37515518593fe3"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "id": "1476698308286504962",
#             "author_id": "593974692",
#             "created_at": "2021-12-30T23:34:47.000Z",
#             "conversation_id": "1476697314156847105",
#             "text": "@ZeeMUFC @zeeshanclvx is a fraud there\u2019s only room for one Zee",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476697801316831236"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 8,
#                         "username": "ZeeMUFC",
#                         "id": "1210101141922615296"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "315b740b108481f6"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1210101141922615296"
#         },
#         {
#             "id": "1476697485506658305",
#             "author_id": "24647508",
#             "created_at": "2021-12-30T23:31:30.000Z",
#             "conversation_id": "1476244850508976137",
#             "text": "@highland_mn @GuildAppleton @krhamak @Random_Bod @ThamesVP You should be arrested and the negligent police reprimanded. Still wouldn\u2019t call for the CC to resign though\u2026",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476660225998733313"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 12,
#                         "username": "highland_mn",
#                         "id": "964255860439617538"
#                     },
#                     {
#                         "start": 13,
#                         "end": 27,
#                         "username": "GuildAppleton",
#                         "id": "3123390338"
#                     },
#                     {
#                         "start": 28,
#                         "end": 36,
#                         "username": "krhamak",
#                         "id": "917297294"
#                     },
#                     {
#                         "start": 49,
#                         "end": 58,
#                         "username": "ThamesVP",
#                         "id": "134747324"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "460c5314e8a33c64"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "964255860439617538"
#         },
#         {
#             "id": "1476697089618989060",
#             "author_id": "393586901",
#             "created_at": "2021-12-30T23:29:56.000Z",
#             "conversation_id": "1476640096313040901",
#             "text": "@JujuliaGrace @EveryDoctorUK You are brave putting up with the abuse yet carrying on with your important work. Telling the truth using facts , thank you",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476640096313040901"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 13,
#                         "username": "JujuliaGrace",
#                         "id": "1315053256343719936"
#                     },
#                     {
#                         "start": 14,
#                         "end": 28,
#                         "username": "EveryDoctorUK",
#                         "id": "1075356324072972288"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 2,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "6d774ae5e9cf2d96"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1315053256343719936"
#         },
#         {
#             "id": "1476696346887397384",
#             "author_id": "1046019049",
#             "created_at": "2021-12-30T23:26:59.000Z",
#             "conversation_id": "1476628115904475140",
#             "text": "@statsjamie @ToniaBuxton The government KNOWS that those spouting the statistics are inept....\nbut they allow them to continue to do so....\nguilty as charged",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476628119427629056"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 11,
#                         "username": "statsjamie",
#                         "id": "101447362"
#                     },
#                     {
#                         "start": 12,
#                         "end": 24,
#                         "username": "ToniaBuxton",
#                         "id": "362408747"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "6e8ea5f6ac6dd9de"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "101447362"
#         },
#         {
#             "id": "1476694938431729678",
#             "author_id": "165895243",
#             "created_at": "2021-12-30T23:21:23.000Z",
#             "conversation_id": "1476672774869602314",
#             "text": "@LeanneBuchan And the abuse they\u2019ve received recently is mental. \ud83e\udd2c",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476672774869602314"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 13,
#                         "username": "LeanneBuchan",
#                         "id": "46396165"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 1,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "26536f52a64605b5"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "46396165"
#         },
#         {
#             "id": "1476694778595225602",
#             "author_id": "1475373555911176192",
#             "created_at": "2021-12-30T23:20:45.000Z",
#             "conversation_id": "1476694778595225602",
#             "text": "@samaritans Thanks again to the volunteer I spoke to before.\nWoke up in a slightly confused state and dialled my favourite 3 digit number. But apparently POLICE, AMBULANCE currently have no plans to visit our address currently",
#             "source": "Twitter for Android",
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 11,
#                         "username": "samaritans",
#                         "id": "404248209"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "3cf4768fb6083814"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "404248209"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 243,
#                         "end": 245,
#                         "probability": 0.6116,
#                         "type": "Organization",
#                         "normalized_text": "NHS"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 14,
#                         "username": "sally_ghazali",
#                         "id": "3677465417"
#                     },
#                     {
#                         "start": 15,
#                         "end": 27,
#                         "username": "dannyjnwong",
#                         "id": "2885024530"
#                     },
#                     {
#                         "start": 28,
#                         "end": 40,
#                         "username": "metpoliceuk",
#                         "id": "66967746"
#                     },
#                     {
#                         "start": 41,
#                         "end": 52,
#                         "username": "NHSMillion",
#                         "id": "4882743003"
#                     },
#                     {
#                         "start": 53,
#                         "end": 64,
#                         "username": "sajidjavid",
#                         "id": "20052899"
#                     },
#                     {
#                         "start": 65,
#                         "end": 78,
#                         "username": "BorisJohnson",
#                         "id": "3131144855"
#                     },
#                     {
#                         "start": 79,
#                         "end": 92,
#                         "username": "NHSProviders",
#                         "id": "72288745"
#                     },
#                     {
#                         "start": 93,
#                         "end": 104,
#                         "username": "NHSEngland",
#                         "id": "551426814"
#                     },
#                     {
#                         "start": 105,
#                         "end": 116,
#                         "username": "pritipatel",
#                         "id": "61660254"
#                     },
#                     {
#                         "start": 117,
#                         "end": 133,
#                         "username": "AmandaPritchard",
#                         "id": "130082288"
#                     },
#                     {
#                         "start": 134,
#                         "end": 148,
#                         "username": "NHSEnglandNMD",
#                         "id": "1014534275130122242"
#                     },
#                     {
#                         "start": 149,
#                         "end": 162,
#                         "username": "Keir_Starmer",
#                         "id": "2425571623"
#                     },
#                     {
#                         "start": 163,
#                         "end": 169,
#                         "username": "gmcuk",
#                         "id": "492996846"
#                     },
#                     {
#                         "start": 170,
#                         "end": 181,
#                         "username": "CNOEngland",
#                         "id": "613328014"
#                     }
#                 ]
#             },
#             "id": "1476694582469529603",
#             "author_id": "61720851",
#             "created_at": "2021-12-30T23:19:58.000Z",
#             "conversation_id": "1476627569420156938",
#             "text": "@sally_ghazali @dannyjnwong @metpoliceuk @NHSMillion @sajidjavid @BorisJohnson @NHSProviders @NHSEngland @pritipatel @AmandaPritchard @NHSEnglandNMD @Keir_Starmer @gmcuk @CNOEngland I thought zero tolerance to racial abuse was the norm in the NHS. If not, why?! This is one of many increasing attacks on staff and it shouldn\u2019t be acceptable at all!",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476646193321160710"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 2,
#                 "reply_count": 0,
#                 "like_count": 10,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "5de8cffc145c486b"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "3677465417"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 60,
#                         "end": 72,
#                         "probability": 0.5263,
#                         "type": "Other",
#                         "normalized_text": "4th Spiderman"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "start": 190,
#                         "end": 213,
#                         "url": "https://t.co/tMPbcjJ2lT",
#                         "expanded_url": "https://twitter.com/lynnnnseyj/status/1476693347137994754/photo/1",
#                         "display_url": "pic.twitter.com/tMPbcjJ2lT",
#                         "media_key": "3_1476693345195941888"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 6,
#                         "end": 16,
#                         "username": "paulr1208",
#                         "id": "27410429"
#                     }
#                 ]
#             },
#             "id": "1476693347137994754",
#             "author_id": "25357849",
#             "created_at": "2021-12-30T23:15:04.000Z",
#             "conversation_id": "1476693347137994754",
#             "text": "Seems @paulr1208 clearly already prepared himself to be the 4th Spiderman in the next movie...aside from that can't believe it's 2021 &amp; you still have to smuggle snacks into the cinema. https://t.co/tMPbcjJ2lT",
#             "source": "Twitter for Android",
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 3,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "42b23fa9d1cdfb5b"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 153,
#                         "end": 159,
#                         "probability": 0.6699,
#                         "type": "Product",
#                         "normalized_text": "YouTube"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 16,
#                         "username": "Mohamme09073545",
#                         "id": "1272956793497534465"
#                     }
#                 ]
#             },
#             "id": "1476693271695044611",
#             "author_id": "1083273192326742017",
#             "created_at": "2021-12-30T23:14:46.000Z",
#             "conversation_id": "1476364418090999817",
#             "text": "@Mohamme09073545 I could only watch the first couple of videos. Common law court? WTF, is he on about? These people are dangerous and watch far too many YouTube videos. Acting like they know it all, when they know sod all. They are a danger to that man, &amp; should be arrested.",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476364418090999817"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 1,
#                 "reply_count": 0,
#                 "like_count": 22,
#                 "quote_count": 1
#             },
#             "geo": {
#                 "place_id": "1d25440933eb512c"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1272956793497534465"
#         },
#         {
#             "id": "1476692995927945220",
#             "author_id": "417417978",
#             "created_at": "2021-12-30T23:13:40.000Z",
#             "conversation_id": "1476692995927945220",
#             "entities": {
#                 "urls": [
#                     {
#                         "start": 108,
#                         "end": 131,
#                         "url": "https://t.co/jnMVz5RV67",
#                         "expanded_url": "https://twitter.com/999London/status/1476686346831998983",
#                         "display_url": "twitter.com/999London/stat\u2026"
#                     }
#                 ]
#             },
#             "text": "Another young lad losing his life to knife crime and so close to home.\ud83d\ude21\ud83d\ude22.\n\nCondolences to his poor family.\ud83d\udc94 https://t.co/jnMVz5RV67",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "quoted",
#                     "id": "1476686346831998983"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 8,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "135989ad972a5d9d"
#             },
#             "reply_settings": "everyone"
#         },
#         {
#             "id": "1476690725429518336",
#             "author_id": "43529427",
#             "created_at": "2021-12-30T23:04:39.000Z",
#             "conversation_id": "1476644633115607044",
#             "text": "@paulothegreat @planepimp @MickDennisReal @henrywinter I don't know how many times I have to say the abuse he received was wrong to demonstrate that I do have a problem with it?",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476688962769100808"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 14,
#                         "username": "paulothegreat",
#                         "id": "25397869"
#                     },
#                     {
#                         "start": 15,
#                         "end": 25,
#                         "username": "planepimp",
#                         "id": "1126399888462438401"
#                     },
#                     {
#                         "start": 26,
#                         "end": 41,
#                         "username": "MickDennisReal",
#                         "id": "2149338685"
#                     },
#                     {
#                         "start": 42,
#                         "end": 54,
#                         "username": "henrywinter",
#                         "id": "37896651"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 1,
#                 "like_count": 0,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "0c2f185415d757e3"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "25397869"
#         },
#         {
#             "entities": {
#                 "annotations": [
#                     {
#                         "start": 40,
#                         "end": 42,
#                         "probability": 0.6475,
#                         "type": "Organization",
#                         "normalized_text": "MI5"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "start": 158,
#                         "end": 181,
#                         "url": "https://t.co/MBpHMsq93o",
#                         "expanded_url": "https://blog.michaeleastwriter.com/lord-louis-mountbatten-pedophile-traitor-above-the-law-cfa397680298",
#                         "display_url": "blog.michaeleastwriter.com/lord-louis-mou\u2026",
#                         "images": [
#                             {
#                                 "url": "https://pbs.twimg.com/news_img/1526547432661712896/fQNP-7oy?format=jpg&name=orig",
#                                 "width": 1200,
#                                 "height": 675
#                             },
#                             {
#                                 "url": "https://pbs.twimg.com/news_img/1526547432661712896/fQNP-7oy?format=jpg&name=150x150",
#                                 "width": 150,
#                                 "height": 150
#                             }
#                         ],
#                         "status": 200,
#                         "title": "Lord Louis Mountbatten: Pedophile. Traitor. Above the Law.",
#                         "description": "How the Crimes of a \u201cNational Hero\u201d May Eclipse Even Those of Jimmy Savile and Why Nobody Wants to Talk About It",
#                         "unwound_url": "https://blog.michaeleastwriter.com/lord-louis-mountbatten-pedophile-traitor-above-the-law-cfa397680298"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 14,
#                         "username": "MarinaPurkiss",
#                         "id": "58436094"
#                     }
#                 ]
#             },
#             "id": "1476689661925994503",
#             "author_id": "2610456553",
#             "created_at": "2021-12-30T23:00:25.000Z",
#             "conversation_id": "1476680765895290887",
#             "text": "@MarinaPurkiss The police maybe thought MI5 and MI6 would stop them as per usual? Covering up child rape and shielding paedophile rings has always happened.  https://t.co/MBpHMsq93o",
#             "source": "Twitter for Android",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476680765895290887"
#                 }
#             ],
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 1,
#                 "reply_count": 2,
#                 "like_count": 11,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "28679b23ed15b380"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "58436094"
#         },
#         {
#             "id": "1476689399526182919",
#             "author_id": "701149256",
#             "created_at": "2021-12-30T22:59:23.000Z",
#             "conversation_id": "1476470269267124227",
#             "text": "@LeeHurstComic Oh look, let\u2019s all sign up and make sure we notify the police of where this clod is planning latest law breaking.  What an epic fail\u2026what a surprise.  Mind you it\u2019s the only way anyone will show up\u2026.",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476470269267124227"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 14,
#                         "username": "LeeHurstComic",
#                         "id": "1289910485685501952"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 0,
#                 "like_count": 1,
#                 "quote_count": 0
#             },
#             "geo": {
#                 "place_id": "6f5c95da3e1c9998"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "1289910485685501952"
#         },
#         {
#             "id": "1476689239073079299",
#             "author_id": "1626283772",
#             "created_at": "2021-12-30T22:58:44.000Z",
#             "conversation_id": "1476653329061134338",
#             "text": "@timshires Too right, inciting the crowd should be police issue as well.",
#             "source": "Twitter for iPhone",
#             "referenced_tweets": [
#                 {
#                     "type": "replied_to",
#                     "id": "1476653329061134338"
#                 }
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 10,
#                         "username": "timshires",
#                         "id": "20847425"
#                     }
#                 ]
#             },
#             "lang": "en",
#             "public_metrics": {
#                 "retweet_count": 0,
#                 "reply_count": 4,
#                 "like_count": 2,
#                 "quote_count": 3
#             },
#             "geo": {
#                 "place_id": "172253e997f41ced"
#             },
#             "reply_settings": "everyone",
#             "in_reply_to_user_id": "20847425"
#         },
#         {
#             "id": "1476689011720794112",
#             "author_id": "912797464150855681",
#             "created_at": "2021-12-30T22:57:50.000Z",
#             "conversation_id": "1476610104472518661",
#             "entities": {
#                 "urls": [
#                     {
#                         "start": 201,
#                         "end": 224,
#                         "url": "https://t.co/J57JV4ggld",
#                         "expanded_url": "https://www.twobirds.com/en/news/articles/2021/australia/non-fungible-tokens-nfts-and-copyright-law",
#                         "display_url": "twobirds.com/en/news/articl\u2026",
#                         "status": 200,
#                         "title": "Non-fungible tokens (NFTs) and copyright law",
#                         "description": "A topic at the edge of intellectual property law is the ambiguous relationship between non-fungible tokens (NFTs) and copyright law. NFTs have been put under the spotlight this year, as several sales of NFTs recorded purchase prices exceeding a million dollars.",
#                         "unwound_url": "https://www.twobirds.com/en/insights/2021/australia/non-fungible-tokens-nfts-and-copyright-law"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "start": 0,
#                         "end": 12,
#                         "username": "Inselaffe76",
#                         "id": "472442338"
#                     }
# ...
#                 },
#                 "country": "United Kingdom",
#                 "name": "Beddau",
#                 "country_code": "GB",
#                 "full_name": "Beddau, Wales",
#                 "place_type": "city"
#             },
#             {
#                 "id": "13dd0eca94d322f1",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         0.3836341,
#                         51.5463777,
#                         0.530637,
#                         51.594472
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Basildon",
#                 "country_code": "GB",
#                 "full_name": "Basildon, East",
#                 "place_type": "city"
#             },
#             {
#                 "id": "76e86fe6165873ae",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -0.3256344,
#                         51.29649,
#                         -0.278763,
#                         51.3241978
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Ashtead",
#                 "country_code": "GB",
#                 "full_name": "Ashtead, South East",
#                 "place_type": "city"
#             },
#             {
#                 "id": "41edfddd44554faa",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -3.479842,
#                         53.285031,
#                         -3.4551956,
#                         53.2992957
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Rhuddlan",
#                 "country_code": "GB",
#                 "full_name": "Rhuddlan, Wales",
#                 "place_type": "city"
#             },
#             {
#                 "id": "073fac87d03bed4b",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -4.744634,
#                         50.454405,
#                         -4.6974737,
#                         50.4802039
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Bodmin",
#                 "country_code": "GB",
#                 "full_name": "Bodmin, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "3368b5e9f8f1a276",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -3.3918431,
#                         51.1587965,
#                         -3.3807443,
#                         51.1632899
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Bilbrook",
#                 "country_code": "GB",
#                 "full_name": "Bilbrook, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "0f4e16e27e637b40",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -3.3354357,
#                         51.5495629,
#                         -3.288995,
#                         51.577064
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Church Village",
#                 "country_code": "GB",
#                 "full_name": "Church Village, Wales",
#                 "place_type": "city"
#             },
#             {
#                 "id": "513372d74ee7530b",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -4.665446,
#                         55.425487,
#                         -4.5843871,
#                         55.506649
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Ayr",
#                 "country_code": "GB",
#                 "full_name": "Ayr, Scotland",
#                 "place_type": "city"
#             },
#             {
#                 "id": "3eb1d4cd2329c3a8",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -0.6580703,
#                         51.687386,
#                         -0.5814257,
#                         51.726722
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Chesham",
#                 "country_code": "GB",
#                 "full_name": "Chesham, South East",
#                 "place_type": "city"
#             },
#             {
#                 "id": "119b194b6bbb3bea",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -4.44813,
#                         55.847615,
#                         -4.356847,
#                         55.888957
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Renfrew",
#                 "country_code": "GB",
#                 "full_name": "Renfrew, Scotland",
#                 "place_type": "city"
#             },
#             {
#                 "id": "4d9ad36e405769a3",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -1.331762,
#                         53.6729485,
#                         -1.2770327,
#                         53.708743
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Pontefract",
#                 "country_code": "GB",
#                 "full_name": "Pontefract, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "76bbeb89d889d1b5",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -5.2462348,
#                         55.895501,
#                         -5.227568,
#                         55.9126238
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Tighnabruaich",
#                 "country_code": "GB",
#                 "full_name": "Tighnabruaich, Scotland",
#                 "place_type": "city"
#             },
#             {
#                 "id": "305d1c7ecdf99e37",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -3.364431,
#                         51.557104,
#                         -3.260433,
#                         51.6300116
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Pontypridd",
#                 "country_code": "GB",
#                 "full_name": "Pontypridd, Wales",
#                 "place_type": "city"
#             },
#             {
#                 "id": "3b4abe7dce81813a",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -2.185708,
#                         53.492866,
#                         -2.048031,
#                         53.592865
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Oldham",
#                 "country_code": "GB",
#                 "full_name": "Oldham, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "174aa071dce6ffd4",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -1.5043785,
#                         54.948281,
#                         -1.377026,
#                         55.00756
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "South Shields",
#                 "country_code": "GB",
#                 "full_name": "South Shields, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "5e7b3f6ed436a3f9",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -1.560293,
#                         52.2722133,
#                         -1.5025468,
#                         52.314312
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Leamington Spa",
#                 "country_code": "GB",
#                 "full_name": "Leamington Spa, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "064b670c43d8d701",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -0.147596,
#                         53.52505,
#                         -0.0093573,
#                         53.587884
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Grimsby",
#                 "country_code": "GB",
#                 "full_name": "Grimsby, England",
#                 "place_type": "city"
#             },
#             {
#                 "id": "5c5527129aecd398",
#                 "geo": {
#                     "type": "Feature",
#                     "bbox": [
#                         -7.3595434,
#                         54.9697857,
#                         -7.2663468,
#                         55.0425905
#                     ],
#                     "properties": {}
#                 },
#                 "country": "United Kingdom",
#                 "name": "Londonderry",
#                 "country_code": "GB",
#                 "full_name": "Londonderry, Northern Ireland",
#                 "place_type": "city"
#             }
#         ]
#     },
#     "errors": [
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1210101141922615296",
#             "value": "1210101141922615296",
#             "detail": "User has been suspended: [1210101141922615296].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1336362156745486345",
#             "value": "1336362156745486345",
#             "detail": "User has been suspended: [1336362156745486345].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "value": "1427608243644387344",
#             "detail": "Could not find user with in_reply_to_user_id: [1427608243644387344].",
#             "title": "Not Found Error",
#             "resource_type": "user",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1427608243644387344",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "value": "1137044930373832706",
#             "detail": "Could not find user with in_reply_to_user_id: [1137044930373832706].",
#             "title": "Not Found Error",
#             "resource_type": "user",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1137044930373832706",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "value": "822789576410402816",
#             "detail": "Could not find user with in_reply_to_user_id: [822789576410402816].",
#             "title": "Not Found Error",
#             "resource_type": "user",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "822789576410402816",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1432435725811736579",
#             "value": "1432435725811736579",
#             "detail": "User has been suspended: [1432435725811736579].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1386046939955830785",
#             "value": "1386046939955830785",
#             "detail": "User has been suspended: [1386046939955830785].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1679362640",
#             "value": "1679362640",
#             "detail": "User has been suspended: [1679362640].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1388588637969866752",
#             "value": "1388588637969866752",
#             "detail": "User has been suspended: [1388588637969866752].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "value": "2255315445",
#             "detail": "Could not find user with in_reply_to_user_id: [2255315445].",
#             "title": "Not Found Error",
#             "resource_type": "user",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "2255315445",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1399891470405062661",
#             "value": "1399891470405062661",
#             "detail": "User has been suspended: [1399891470405062661].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1070013719646744576",
#             "value": "1070013719646744576",
#             "detail": "User has been suspended: [1070013719646744576].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1356754872113258496",
#             "value": "1356754872113258496",
#             "detail": "User has been suspended: [1356754872113258496].",
#             "title": "Forbidden",
#             "resource_type": "user",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         },
#         {
#             "value": "812025421269237760",
#             "detail": "Could not find user with in_reply_to_user_id: [812025421269237760].",
#             "title": "Not Found Error",
#             "resource_type": "user",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "812025421269237760",
#             "type": "https://api.twitter.com/2/problems/resource-not-found"
#         }
#     ],
#     "meta": {
#         "newest_id": "1476703915957698564",
#         "oldest_id": "1476522173456130050",
#         "result_count": 492,
#         "next_token": "b26v89c19zqg8o3fpe17vaamnlmgc5z7n9jt65loqjiwt"
#     }
# }

# %%
# Create file
csvFile = open("TWEETS.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo','id','language','source','tweet', 'location', 'bbox'])
csvFile.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation - placeid
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 5. Tweet ID
        tweet_id = tweet['id']

        # 6. Language
        lang = tweet['lang']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
                
        # 9. Location name
        for place in json_response['includes']['places']:
            
            if (tweet['geo']['place_id'] == place['id']):
                location = place['full_name']
                bbox = place['geo']['bbox']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, source, text, location, bbox]

        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "(abduct OR abuse OR arrested OR arson OR assault OR burglary OR charged OR convicted OR crime OR cybercrime OR fraud OR homicide OR investigation OR jailed OR kidnap OR knifecrime OR manslaughter OR molestation OR murder police OR rape OR robbery OR seized OR sentenced OR shooting OR smuggle OR smuggling OR stabbing OR theft OR trafficking OR vandalism) place_country:GB has:geo -is:nullcast -is:retweet lang:en"
start_list =    ['2021-01-01T00:00:00.000Z',
                 '2021-02-01T00:00:00.000Z',
                 '2021-03-01T00:00:00.000Z',
                 '2021-04-01T00:00:00.000Z',
                 '2021-05-01T00:00:00.000Z',
                 '2021-06-01T00:00:00.000Z',
                 '2021-07-01T00:00:00.000Z',
                 '2021-08-01T00:00:00.000Z',
                 '2021-09-01T00:00:00.000Z',
                 '2021-10-01T00:00:00.000Z',
                 '2021-11-01T00:00:00.000Z',
                 '2021-12-01T00:00:00.000Z']

end_list =      ['2021-01-31T00:00:00.000Z',
                 '2021-02-28T00:00:00.000Z',
                 '2021-03-31T00:00:00.000Z',
                 '2021-04-30T00:00:00.000Z',
                 '2021-05-31T00:00:00.000Z',
                 '2021-06-30T00:00:00.000Z',
                 '2021-07-31T00:00:00.000Z',
                 '2021-08-31T00:00:00.000Z',
                 '2021-09-30T00:00:00.000Z',
                 '2021-10-31T00:00:00.000Z',
                 '2021-11-30T00:00:00.000Z',
                 '2021-12-31T00:00:00.000Z']
max_results = 500

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open("TWEETS.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)


for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 50000 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            
            if result_count is not None and result_count > 0 and next_token is not None:
                
                append_to_csv(json_response, "TWEETS.csv")
                count += result_count
                total_tweets += result_count
                
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                
                append_to_csv(json_response, "TWEETS.csv")
                count += result_count
                total_tweets += result_count
                
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
# Out:
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  471
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  494
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  91
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  468
# Endpoint Response Code: 200
# # of Tweets added from this response:  472
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  472
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  453
# Endpoint Response Code: 200
# # of Tweets added from this response:  360
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  439
# Endpoint Response Code: 200
# # of Tweets added from this response:  376
# Endpoint Response Code: 200
# # of Tweets added from this response:  381
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  442
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  400
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  472
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  494
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  475
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  494
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  466
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  470
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  470
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  469
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  26
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  495
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  475
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  5
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  472
# Endpoint Response Code: 200
# # of Tweets added from this response:  470
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  476
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  479
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  475
# Endpoint Response Code: 200
# # of Tweets added from this response:  472
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  385
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  473
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  477
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  483
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  475
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  478
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  474
# Endpoint Response Code: 200
# # of Tweets added from this response:  131
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  485
# Endpoint Response Code: 200
# # of Tweets added from this response:  466
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  484
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  480
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  490
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  492
# Endpoint Response Code: 200
# # of Tweets added from this response:  495
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  488
# Endpoint Response Code: 200
# # of Tweets added from this response:  481
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  493
# Endpoint Response Code: 200
# # of Tweets added from this response:  482
# Endpoint Response Code: 200
# # of Tweets added from this response:  491
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  487
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# Endpoint Response Code: 200
# # of Tweets added from this response:  489
# Endpoint Response Code: 200
# # of Tweets added from this response:  63

# %% [markdown]
# <h2>References : </h2>
#
# https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a
#
# https://muhark.github.io/python/scraping/tutorial/2021/03/25/getting-started-with-academic-twitter.html
#
# backup - https://towardsdatascience.com/searching-for-tweets-with-python-f659144b225f
#
# bounding box - https://boundingbox.klokantech.com/
